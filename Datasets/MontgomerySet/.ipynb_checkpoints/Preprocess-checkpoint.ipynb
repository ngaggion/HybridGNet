# %%
import cv2 
import pathlib
import re
import matplotlib.pyplot as plt
import numpy as np

def natural_key(string_):
    """See http://www.codinghorror.com/blog/archives/001018.html"""
    return [int(s) if s.isdigit() else s for s in re.split(r'(\d+)', string_)]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6242/2122511681.py in <module>
# ----> 1 import cv2
#       2 import pathlib
#       3 import re
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img_path = "CXR_png/"
left_mask = "ManualMask/leftMask/"
right_mask = "ManualMask/rightMask/"

data_root = pathlib.Path(img_path)
all_files = list(data_root.glob('*.png'))
all_files = [str(path) for path in all_files]
all_files.sort(key = natural_key)

save_img = "Prep/Images/"
save_seg = "Prep/Masks/"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6242/4032310258.py in <module>
#       3 right_mask = "ManualMask/rightMask/"
#       4
# ----> 5 data_root = pathlib.Path(img_path)
#       6 all_files = list(data_root.glob('*.png'))
#       7 all_files = [str(path) for path in all_files]
#
# NameError: name 'pathlib' is not defined

# %%
file = all_files[0]

i = 1

for file in all_files:
    print('File', i, 'of', len(all_files))

    seg_L = file.replace(img_path, left_mask)
    seg_R = file.replace(img_path, right_mask)

    img = cv2.imread(file, 0)
    segL = cv2.imread(seg_L, 0)
    segR = cv2.imread(seg_R, 0)
    seg = cv2.bitwise_or(segL, segR)

    gray = 255*(img > 1) # To invert the text to white
    coords = cv2.findNonZero(gray) # Find all non-zero points (text)

    x, y, w, h = cv2.boundingRect(coords) # Find minimum spanning bounding box
    cropimg = img[y:y+h, x:x+w] # Crop the image - note we do this on the original image
    cropseg = seg[y:y+h, x:x+w]

    shape = cropimg.shape

    if shape[0] < shape[1]:
        pad = (shape[1] - shape[0])    
        
        if pad % 2 == 1:
            pad = pad // 2
            pad_y = [pad, pad+1]
        else:
            pad = pad // 2
            pad_y = [pad, pad]
            
        pad_x = [0, 0]
    elif shape[1] < shape[0]:
        pad = (shape[0] - shape[1]) 
        
        if pad % 2 == 1:
            pad = pad // 2
            pad_x = [pad, pad+1]
        else:
            pad = pad // 2
            pad_x = [pad, pad]
            
        pad_y = [0, 0]

    img = np.pad(cropimg, pad_width = [pad_y, pad_x])    
    seg = np.pad(cropseg, pad_width = [pad_y, pad_x]) 

    if img.shape[0] != img.shape[1]:
        print('Error padding image')
        break

    if seg.shape[0] != seg.shape[1]:
        print('Error padding seg')
        break

    img_ = cv2.resize(img, [1024, 1024])
    seg_ = cv2.resize(seg, [1024, 1024])

    cv2.imwrite(file.replace(img_path, save_img), img_)
    cv2.imwrite(file.replace(img_path, save_seg), seg_)

    i = i+1
# Out:
# File 1 of 138
# File 2 of 138
# File 3 of 138
# File 4 of 138
# File 5 of 138
# File 6 of 138
# File 7 of 138
# File 8 of 138
# File 9 of 138
# File 10 of 138
# File 11 of 138
# File 12 of 138
# File 13 of 138
# File 14 of 138
# File 15 of 138
# File 16 of 138
# File 17 of 138
# File 18 of 138
# File 19 of 138
# File 20 of 138
# File 21 of 138
# File 22 of 138
# File 23 of 138
# File 24 of 138
# File 25 of 138
# File 26 of 138
# File 27 of 138
# File 28 of 138
# File 29 of 138
# File 30 of 138
# File 31 of 138
# File 32 of 138
# File 33 of 138
# File 34 of 138
# File 35 of 138
# File 36 of 138
# File 37 of 138
# File 38 of 138
# File 39 of 138
# File 40 of 138
# File 41 of 138
# File 42 of 138
# File 43 of 138
# File 44 of 138
# File 45 of 138
# File 46 of 138
# File 47 of 138
# File 48 of 138
# File 49 of 138
# File 50 of 138
# File 51 of 138
# File 52 of 138
# File 53 of 138
# File 54 of 138
# File 55 of 138
# File 56 of 138
# File 57 of 138
# File 58 of 138
# File 59 of 138
# File 60 of 138
# File 61 of 138
# File 62 of 138
# File 63 of 138
# File 64 of 138
# File 65 of 138
# File 66 of 138
# File 67 of 138
# File 68 of 138
# File 69 of 138
# File 70 of 138
# File 71 of 138
# File 72 of 138
# File 73 of 138
# File 74 of 138
# File 75 of 138
# File 76 of 138
# File 77 of 138
# File 78 of 138
# File 79 of 138
# File 80 of 138
# File 81 of 138
# File 82 of 138
# File 83 of 138
# File 84 of 138
# File 85 of 138
# File 86 of 138
# File 87 of 138
# File 88 of 138
# File 89 of 138
# File 90 of 138
# File 91 of 138
# File 92 of 138
# File 93 of 138
# File 94 of 138
# File 95 of 138
# File 96 of 138
# File 97 of 138
# File 98 of 138
# File 99 of 138
# File 100 of 138
# File 101 of 138
# File 102 of 138
# File 103 of 138
# File 104 of 138
# File 105 of 138
# File 106 of 138
# File 107 of 138
# File 108 of 138
# File 109 of 138
# File 110 of 138
# File 111 of 138
# File 112 of 138
# File 113 of 138
# File 114 of 138
# File 115 of 138
# File 116 of 138
# File 117 of 138
# File 118 of 138
# File 119 of 138
# File 120 of 138
# File 121 of 138
# File 122 of 138
# File 123 of 138
# File 124 of 138
# File 125 of 138
# File 126 of 138
# File 127 of 138
# File 128 of 138
# File 129 of 138
# File 130 of 138
# File 131 of 138
# File 132 of 138
# File 133 of 138
# File 134 of 138
# File 135 of 138
# File 136 of 138
# File 137 of 138
# File 138 of 138
